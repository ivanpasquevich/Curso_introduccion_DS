# %% [markdown]
# # Trabajando con datos reales !!!
#
# Ahora comienza lo divertido, basta de teoria y vamos a explorar datos reales.
#
# Para ello primero debemos cargar esos datos en un dataframe, dichos datos pueden provenir de distintos archivos (.csv, .xml, .html , .json , .parquet , entre otros)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **.csv**
#
# Es uno de los formatos mas comunes para el almacenamiento de datos, por lo que vamos a leer archivos con esta extension.

# %%
pd.read_

# %%
datos = pd.read_csv("playas_estacionamiento.csv")
# sep
# nrows

# %%
datos
# Out:
#       NOMENCLATURA                         Dirección Resolución habilitacion  \
# 0    04-02-003-031                  12 DE octubre 81                772/2015
# 1    04-03-046-023                   25 DE mayo 0337               0465/2017
# 2    04-03-053-006                   25 DE mayo 0342                776/2015
# 3    01-25-033-040                   25 DE mayo 0955               1090/2007
# 4    06-11-038-012  27 DE ABRIL 1900 / Ing. Lopez 98               0466/2017
# ..             ...                               ...                     ...
# 342  04-08-023-072               VELEZ SARSFIELD 854                428/2014
# 343  04-08-023-021               VELEZ SARSFIELD 864               1248/2007
# 344  04-09-041-034               VELEZ SARSFIELD 869                318/2015
# 345  01-26-036-051                      VIAMONTE 248                136/2014
# 346            NaN                               NaN                     NaN
#
#     Vencimiento habilitacion  Capacidad automoviles  capacidad bicicletas
# 0                 14-may.-18                     31                   8.0
# 1                 30-dic.-17                     33                   8.0
# 2                 28-feb.-18                     13                   NaN
# 3                 14-jun.-15                     27                   8.0
# 4                 30-dic.-17                     24                   8.0
# ..                       ...                    ...                   ...
# 342               31-mar.-17                     20                   8.0
# 343               14-jun.-15                     12                   NaN
# 344                14-sep-16                     40                   8.0
# 345               02-abr.-19                     71                  16.0
# 346                      NaN                  21290                4200.0
#
# [347 rows x 6 columns]

# %%
datos.head()
# Out:
#     NOMENCLATURA                         Dirección Resolución habilitacion  \
# 0  04-02-003-031                  12 DE octubre 81                772/2015
# 1  04-03-046-023                   25 DE mayo 0337               0465/2017
# 2  04-03-053-006                   25 DE mayo 0342                776/2015
# 3  01-25-033-040                   25 DE mayo 0955               1090/2007
# 4  06-11-038-012  27 DE ABRIL 1900 / Ing. Lopez 98               0466/2017
#
#   Vencimiento habilitacion  Capacidad automoviles  capacidad bicicletas
# 0               14-may.-18                     31                   8.0
# 1               30-dic.-17                     33                   8.0
# 2               28-feb.-18                     13                   NaN
# 3               14-jun.-15                     27                   8.0
# 4               30-dic.-17                     24                   8.0

# %%
datos.tail()
# Out:
#       NOMENCLATURA            Dirección Resolución habilitacion  \
# 342  04-08-023-072  VELEZ SARSFIELD 854                428/2014
# 343  04-08-023-021  VELEZ SARSFIELD 864               1248/2007
# 344  04-09-041-034  VELEZ SARSFIELD 869                318/2015
# 345  01-26-036-051         VIAMONTE 248                136/2014
# 346            NaN                  NaN                     NaN
#
#     Vencimiento habilitacion  Capacidad automoviles  capacidad bicicletas
# 342               31-mar.-17                     20                   8.0
# 343               14-jun.-15                     12                   NaN
# 344                14-sep-16                     40                   8.0
# 345               02-abr.-19                     71                  16.0
# 346                      NaN                  21290                4200.0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NOMENCLATURA              344 non-null    object
#  1   Dirección                 346 non-null    object
#  2   Resolución habilitacion   345 non-null    object
#  3   Vencimiento habilitacion  345 non-null    object
#  4   Capacidad automoviles     347 non-null    int64
#  5   capacidad bicicletas      325 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 16.4+ KB

# %%
datos.describe()
# Out:
#        Capacidad automoviles  capacidad bicicletas
# count             347.000000            325.000000
# mean              122.708934             25.846154
# std              1141.094713            232.339340
# min                 5.000000              8.000000
# 25%                25.000000              8.000000
# 50%                41.000000              8.000000
# 75%                81.000000             16.000000
# max             21290.000000           4200.000000

# %%
# agarremos los nombres de las columnas
datos.columns
# Out:
# Index(['NOMENCLATURA', 'Dirección', 'Resolución habilitacion',
#        'Vencimiento habilitacion', 'Capacidad automoviles',
#        'capacidad bicicletas'],
#       dtype='object')

# %%
# podemos pasarlos a una lista para usar las propiedades de una lista 
datos.columns.to_list()
# Out:
# ['NOMENCLATURA',
#  'Dirección',
#  'Resolución habilitacion',
#  'Vencimiento habilitacion',
#  'Capacidad automoviles',
#  'capacidad bicicletas']

# %%
# supongamos que queremos cambiar el nombre de una columna
# usamos la funcion rename

datos.rename({'NOMENCLATURA':'Nomenclatura'},axis=1)
# Out:
#       Nomenclatura                         Dirección Resolución habilitacion  \
# 0    04-02-003-031                  12 DE octubre 81                772/2015
# 1    04-03-046-023                   25 DE mayo 0337               0465/2017
# 2    04-03-053-006                   25 DE mayo 0342                776/2015
# 3    01-25-033-040                   25 DE mayo 0955               1090/2007
# 4    06-11-038-012  27 DE ABRIL 1900 / Ing. Lopez 98               0466/2017
# ..             ...                               ...                     ...
# 342  04-08-023-072               VELEZ SARSFIELD 854                428/2014
# 343  04-08-023-021               VELEZ SARSFIELD 864               1248/2007
# 344  04-09-041-034               VELEZ SARSFIELD 869                318/2015
# 345  01-26-036-051                      VIAMONTE 248                136/2014
# 346            NaN                               NaN                     NaN
#
#     Vencimiento habilitacion  Capacidad automoviles  capacidad bicicletas
# 0                 14-may.-18                     31                   8.0
# 1                 30-dic.-17                     33                   8.0
# 2                 28-feb.-18                     13                   NaN
# 3                 14-jun.-15                     27                   8.0
# 4                 30-dic.-17                     24                   8.0
# ..                       ...                    ...                   ...
# 342               31-mar.-17                     20                   8.0
# 343               14-jun.-15                     12                   NaN
# 344                14-sep-16                     40                   8.0
# 345               02-abr.-19                     71                  16.0
# 346                      NaN                  21290                4200.0
#
# [347 rows x 6 columns]

# %%
datos.head()
# Out:
#       NOMENCLATURA                         Dirección Resolución habilitacion  \
# 0    04-02-003-031                  12 DE octubre 81                772/2015
# 1    04-03-046-023                   25 DE mayo 0337               0465/2017
# 2    04-03-053-006                   25 DE mayo 0342                776/2015
# 3    01-25-033-040                   25 DE mayo 0955               1090/2007
# 4    06-11-038-012  27 DE ABRIL 1900 / Ing. Lopez 98               0466/2017
# ..             ...                               ...                     ...
# 342  04-08-023-072               VELEZ SARSFIELD 854                428/2014
# 343  04-08-023-021               VELEZ SARSFIELD 864               1248/2007
# 344  04-09-041-034               VELEZ SARSFIELD 869                318/2015
# 345  01-26-036-051                      VIAMONTE 248                136/2014
# 346            NaN                               NaN                     NaN
#
#     Vencimiento habilitacion  Capacidad automoviles  capacidad bicicletas
# 0                 14-may.-18                     31                   8.0
# 1                 30-dic.-17                     33                   8.0
# 2                 28-feb.-18                     13                   NaN
# 3                 14-jun.-15                     27                   8.0
# 4                 30-dic.-17                     24                   8.0
# ..                       ...                    ...                   ...
# 342               31-mar.-17                     20                   8.0
# 343               14-jun.-15                     12                   NaN
# 344                14-sep-16                     40                   8.0
# 345               02-abr.-19                     71                  16.0
# 346                      NaN                  21290                4200.0
#
# [347 rows x 6 columns]

# %%
datos.rename({'NOMENCLATURA':'Nomenclatura'},axis=1,inplace=True)

# %%
datos.head()
# Out:
#     Nomenclatura                         Dirección Resolución habilitacion  \
# 0  04-02-003-031                  12 DE octubre 81                772/2015
# 1  04-03-046-023                   25 DE mayo 0337               0465/2017
# 2  04-03-053-006                   25 DE mayo 0342                776/2015
# 3  01-25-033-040                   25 DE mayo 0955               1090/2007
# 4  06-11-038-012  27 DE ABRIL 1900 / Ing. Lopez 98               0466/2017
#
#   Vencimiento habilitacion  Capacidad automoviles  capacidad bicicletas
# 0               14-may.-18                     31                   8.0
# 1               30-dic.-17                     33                   8.0
# 2               28-feb.-18                     13                   NaN
# 3               14-jun.-15                     27                   8.0
# 4               30-dic.-17                     24                   8.0

# %%
# que pasa si quiero cambiar los nombres de todas las columnas
# puedo hacerlo de esta manera

datos.columns = 'Nom Dir Res_habilitacion Ven_habilitacion Cap_autos Cap_bicis'.split()

# %%
datos
# Out:
#                Nom                               Dir Res_habilitacion  \
# 0    04-02-003-031                  12 DE octubre 81         772/2015
# 1    04-03-046-023                   25 DE mayo 0337        0465/2017
# 2    04-03-053-006                   25 DE mayo 0342         776/2015
# 3    01-25-033-040                   25 DE mayo 0955        1090/2007
# 4    06-11-038-012  27 DE ABRIL 1900 / Ing. Lopez 98        0466/2017
# ..             ...                               ...              ...
# 342  04-08-023-072               VELEZ SARSFIELD 854         428/2014
# 343  04-08-023-021               VELEZ SARSFIELD 864        1248/2007
# 344  04-09-041-034               VELEZ SARSFIELD 869         318/2015
# 345  01-26-036-051                      VIAMONTE 248         136/2014
# 346            NaN                               NaN              NaN
#
#     Ven_habilitacion  Cap_autos  Cap_bicis
# 0         14-may.-18         31        8.0
# 1         30-dic.-17         33        8.0
# 2         28-feb.-18         13        NaN
# 3         14-jun.-15         27        8.0
# 4         30-dic.-17         24        8.0
# ..               ...        ...        ...
# 342       31-mar.-17         20        8.0
# 343       14-jun.-15         12        NaN
# 344        14-sep-16         40        8.0
# 345       02-abr.-19         71       16.0
# 346              NaN      21290     4200.0
#
# [347 rows x 6 columns]

# %%
datos.columns
# Out:
# Index(['Nom', 'Dir', 'Res_habilitacion', 'Ven_habilitacion', 'Cap_autos',
#        'Cap_bicis'],
#       dtype='object')

# %%
# reordenar las columnas
cols = datos.columns.to_list()
print(cols)

cols = cols[:2] + cols[-2:] + cols[2:4]
print(cols)

datos = datos[cols]

datos
# Out:
# ['Nom', 'Dir', 'Res_habilitacion', 'Ven_habilitacion', 'Cap_autos', 'Cap_bicis']
# ['Nom', 'Dir', 'Cap_autos', 'Cap_bicis', 'Res_habilitacion', 'Ven_habilitacion']
#                Nom                               Dir  Cap_autos  Cap_bicis  \
# 0    04-02-003-031                  12 DE octubre 81         31        8.0
# 1    04-03-046-023                   25 DE mayo 0337         33        8.0
# 2    04-03-053-006                   25 DE mayo 0342         13        NaN
# 3    01-25-033-040                   25 DE mayo 0955         27        8.0
# 4    06-11-038-012  27 DE ABRIL 1900 / Ing. Lopez 98         24        8.0
# ..             ...                               ...        ...        ...
# 342  04-08-023-072               VELEZ SARSFIELD 854         20        8.0
# 343  04-08-023-021               VELEZ SARSFIELD 864         12        NaN
# 344  04-09-041-034               VELEZ SARSFIELD 869         40        8.0
# 345  01-26-036-051                      VIAMONTE 248         71       16.0
# 346            NaN                               NaN      21290     4200.0
#
#     Res_habilitacion Ven_habilitacion
# 0           772/2015       14-may.-18
# 1          0465/2017       30-dic.-17
# 2           776/2015       28-feb.-18
# 3          1090/2007       14-jun.-15
# 4          0466/2017       30-dic.-17
# ..               ...              ...
# 342         428/2014       31-mar.-17
# 343        1248/2007       14-jun.-15
# 344         318/2015        14-sep-16
# 345         136/2014       02-abr.-19
# 346              NaN              NaN
#
# [347 rows x 6 columns]

# %%
# cambiemos el tipo de datos de una columna
#datos['Cap_bicis']
datos['Cap_bicis'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-e4ca88c890c8> in <module>
#       1 # cambiemos el tipo de datos de una columna
# ----> 2 datos['Cap_bicis'].astype(int)
#
# c:\program files\python37\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# c:\program files\python37\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# c:\program files\python37\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     866
#     867         if not np.isfinite(arr).all():
# --> 868             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     869
#     870     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
datos['Cap_bicis'].isna().sum()
# Out:
# 22

# %%
datos['Cap_bicis'].fillna(0)
# Out:
# 0         8.0
# 1         8.0
# 2         0.0
# 3         8.0
# 4         8.0
#         ...
# 342       8.0
# 343       0.0
# 344       8.0
# 345      16.0
# 346    4200.0
# Name: Cap_bicis, Length: 347, dtype: float64

# %%
datos['Cap_bicis'] = datos['Cap_bicis'].fillna(0)

# %%
datos['Cap_bicis'].astype(int)
# Out:
# 0         8
# 1         8
# 2         0
# 3         8
# 4         8
#        ...
# 342       8
# 343       0
# 344       8
# 345      16
# 346    4200
# Name: Cap_bicis, Length: 347, dtype: int32

# %%
datos['Cap_bicis'] = datos['Cap_bicis'].astype(int)

# %% [markdown]
# ## Usemos lo aprendido
#
# Vamos a cargar el dataset de arboles publicos en la ciudad de Buenos Aires
#
# https://data.buenosaires.gob.ar/dataset/arbolado-publico-lineal
#
#
# Y luego respondamos las siguientes preguntas:
#
# 1. Existen valores nulos en nuestro conjunto de datos? Los reemplazamos, eliminamos o que hacemos con ellos?
# 2. Hay valores duplicados?
# 3. Obtengamos las 5 comunas con mas arboles, y mostremos las cantidades de arboles que poseen
# 4. Cuanto mide el arbol mas alto? En donde se encuentra? Hay mas de uno con esta altura?
# 5. Cual es el promedio de la altura de los arboles?

# %%
# hay dos formas de cargar el dataframe
# o bien lo podemos descargar y luego levantarlo desde nuestra direccion local
# o levantarlo copiando el enlace de  descarga como a continuacion

datos_arboles = pd.read_csv("arbolado_publico.csv")
#datos_arboles = pd.read_csv("http://cdn.buenosaires.gob.ar/datosabiertos/datasets/arbolado-publico-lineal/arbolado-publico-lineal-2017-2018.csv")
# Out:
# c:\program files\python37\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (2,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
datos_arboles.head()
# Out:
#         long        lat nro_registro tipo_activ  comuna manzana  \
# 0 -58.378563 -34.594902        26779     Lineal       1     NaN
# 1 -58.381532 -34.592319        30887     Lineal       1     NaN
# 2 -58.379103 -34.591939        30904     Lineal       1     NaN
# 3 -58.380710 -34.591548        31336     Lineal       1     NaN
# 4 -58.380710 -34.591548        31337     Lineal       1     NaN
#
#         calle_nombre calle_altura calle_chapa    direccion_normalizada  \
# 0          Esmeralda         1000        1120           ESMERALDA 1120
# 1  Pellegrini Carlos         1300        1345  PELLEGRINI, CARLOS 1345
# 2             Arroyo          800         848               ARROYO 848
# 3             Arroyo          900         932               ARROYO 932
# 4             Arroyo          900         932               ARROYO 932
#
#   ubicacion       nombre_cientifico ancho_acera estado_plantera  \
# 0       NaN            Tipuana tipu         5.5         Ocupada
# 1    Exacta      Peltophorum dubium         4.5         Ocupada
# 2    Exacta  Fraxinus pennsylvanica           4         Ocupada
# 3        LD  Fraxinus pennsylvanica         NaN         Ocupada
# 4        LA   Jacaranda mimosifolia         NaN         Ocupada
#
#   ubicacion_plantera nivel_plantera  diametro_altura_pecho  altura_arbol
# 0            Regular        A nivel                   88.0          34.0
# 1            Regular        Elevada                    6.0           5.0
# 2            Regular        A nivel                    7.0           6.0
# 3            Regular        A nivel                    9.0          29.0
# 4            Regular        A nivel                   13.0           8.0

# %%
datos_arboles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370180 entries, 0 to 370179
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   long                   354838 non-null  float64
#  1   lat                    354838 non-null  float64
#  2   nro_registro           370180 non-null  object
#  3   tipo_activ             370180 non-null  object
#  4   comuna                 370180 non-null  int64
#  5   manzana                224140 non-null  object
#  6   calle_nombre           370087 non-null  object
#  7   calle_altura           364677 non-null  object
#  8   calle_chapa            363721 non-null  object
#  9   direccion_normalizada  355941 non-null  object
#  10  ubicacion              361884 non-null  object
#  11  nombre_cientifico      370180 non-null  object
#  12  ancho_acera            367083 non-null  object
#  13  estado_plantera        370180 non-null  object
#  14  ubicacion_plantera     368776 non-null  object
#  15  nivel_plantera         368828 non-null  object
#  16  diametro_altura_pecho  369894 non-null  float64
#  17  altura_arbol           365858 non-null  float64
# dtypes: float64(4), int64(1), object(13)
# memory usage: 50.8+ MB

# %% [markdown]
# **1. Existen valores nulos en nuestro conjunto de datos? Los reemplazamos, eliminamos o que hacemos con ellos?**

# %%
# como tratar los valores nulos va a depender muchisimo del problema

# en este caso por ejemplo vemos que la columna manzana tiene varios valores nulos, veamos que mas tenemos alli

# %%
datos_arboles['manzana'].unique()
# Out:
# array([nan, '13', '591', ..., '23y', '488 bis', '126 b'], dtype=object)

# %%
datos_arboles['manzana'].nunique()
# Out:
# 1843

# %%
# optamos por eliminar la columna por la presencia de muchos valores nulos

datos_arboles.drop('manzana',axis=1,inplace=True)

# %%
# que pasa con el ancho de la acera por ejemplo

datos_arboles['altura_arbol']
# Out:
# 0         34.0
# 1          5.0
# 2          6.0
# 3         29.0
# 4          8.0
#           ...
# 370175     7.0
# 370176     8.0
# 370177     8.0
# 370178     8.0
# 370179     8.0
# Name: altura_arbol, Length: 370180, dtype: float64

# %%
datos_arboles['altura_arbol'].unique()
# Out:
# array([34.,  5.,  6., 29.,  8., 15., 12.,  3., 13., 11., 10.,  7., 21.,
#        18., 28., 16.,  9., 14., 17., 30., 20.,  2., 19.,  4., 40., 24.,
#        nan, 25., 22., 23., 35., 27., 26., 33., 39., 31., 32., 38., 36.,
#        37.,  1.])

# %%
datos_arboles['altura_arbol'].mean()
# Out:
# 9.036131504572813

# %%
datos_arboles['altura_arbol'].fillna(datos_arboles['altura_arbol'].mean())
# Out:
# 0         34.0
# 1          5.0
# 2          6.0
# 3         29.0
# 4          8.0
#           ...
# 370175     7.0
# 370176     8.0
# 370177     8.0
# 370178     8.0
# 370179     8.0
# Name: altura_arbol, Length: 370180, dtype: float64

# %%
datos_arboles['altura_arbol'] = datos_arboles['altura_arbol'].fillna(datos_arboles['altura_arbol'].mean())

# %% [markdown]
# **2. Hay valores duplicados?**

# %%
# puede haber valores duplicados? depende mucho de los datos que estemos analizando, por eso siempre es importante tener
# una idea de el tema en el que estamos trabajando

# %%
datos_arboles.drop_duplicates().shape
# Out:
# (370180, 17)

# %%
datos_arboles.shape
# Out:
# (370180, 17)

# %%
# que columna no deberia tener duplicados?
datos_arboles.columns
# Out:
# Index(['long', 'lat', 'nro_registro', 'tipo_activ', 'comuna', 'calle_nombre',
#        'calle_altura', 'calle_chapa', 'direccion_normalizada', 'ubicacion',
#        'nombre_cientifico', 'ancho_acera', 'estado_plantera',
#        'ubicacion_plantera', 'nivel_plantera', 'diametro_altura_pecho',
#        'altura_arbol'],
#       dtype='object')

# %%
datos_arboles['nro_registro'].nunique()
# Out:
# 370180

# %% [markdown]
# **3. Obtengamos las 5 comunas con mas arboles, y mostremos las cantidades de arboles que poseen**

# %%
datos_arboles['comuna'].value_counts().nlargest(5)
# Out:
# 12    38818
# 11    37340
# 9     36405
# 10    33421
# 4     32346
# Name: comuna, dtype: int64

# %% [markdown]
# **4. Cuanto mide el arbol mas alto? En donde se encuentra? Hay mas de uno con esta altura?**

# %%
datos_arboles["altura_arbol"].max()
# Out:
# 40.0

# %%
altura_max = datos_arboles["altura_arbol"].max()
datos_arboles[datos_arboles["altura_arbol"]==altura_max]
# Out:
#              long        lat nro_registro tipo_activ  comuna  \
# 90     -58.381536 -34.592402        35144     Lineal       1
# 28042  -58.394735 -34.613740        40070     Lineal       3
# 76626  -58.443372 -34.608020        42102     Lineal       6
# 81191  -58.430871 -34.615099        52105     Lineal       6
# 83670  -58.430856 -34.615420        55649     Lineal       6
# 83672  -58.430867 -34.615176        55651     Lineal       6
# 84104  -58.430879 -34.614942        55812     Lineal       6
# 95653  -58.436798 -34.637094       318537     Lineal       7
# 110799 -58.455935 -34.621240       407476     Lineal       7
# 110800 -58.455935 -34.621240       407477     Lineal       7
# 110801 -58.455935 -34.621240       407478     Lineal       7
# 110802 -58.455935 -34.621240       407479     Lineal       7
# 110805 -58.455935 -34.621240       407482     Lineal       7
# 110811 -58.455935 -34.621240       407488     Lineal       7
# 117141 -58.477156 -34.684879       378978     Lineal       8
# 161606 -58.505209 -34.655505       309063     Lineal       9
# 176830 -58.504476 -34.614027       313013     Lineal      10
# 203824 -58.477892 -34.609142       169592     Lineal      11
# 208724 -58.481058 -34.609554       183524     Lineal      11
# 209156 -58.461333 -34.612197       183331     Lineal      11
# 241601 -58.493726 -34.550421       129396     Lineal      12
# 248544 -58.473209 -34.550422       144910     Lineal      12
# 254764 -58.478530 -34.569652       153333     Lineal      12
# 258809 -58.479897 -34.576950       161478     Lineal      12
# 261743 -58.481891 -34.575580       168280     Lineal      12
# 265210 -58.507326 -34.576648       176680     Lineal      12
# 267815 -58.499750 -34.574435       180270     Lineal      12
# 268245 -58.502975 -34.587572       176891     Lineal      12
# 284356 -58.459429 -34.566775       108723     Lineal      13
# 298064 -58.462264 -34.544353       145694     Lineal      13
# 305731 -58.404089 -34.581921        76579     Lineal      14
# 308096 -58.445202 -34.569090        80861     Lineal      14
# 317946 -58.422261 -34.577087       104865     Lineal      14
# 322838 -58.473840 -34.580929       208576     Lineal      15
# 325978 -58.473637 -34.580394       210356     Lineal      15
# 360885        NaN        NaN       184069     Lineal      11
#
#                            calle_nombre calle_altura calle_chapa  \
# 90                    Pellegrini Carlos         1300        1337
# 28042                           Sarandí          300         385
# 76626                    Díaz Vélez Av.         5400        5477
# 81191                   Acevedo Eduardo          NaN          48
# 83670                   Acevedo Eduardo          NaN          24
# 83672                   Acevedo Eduardo          NaN          42
# 84104                   Acevedo Eduardo          NaN          62
# 95653                    Castañares Av.         1300        1310
# 110799                   Avellaneda Av.         1800        1800
# 110800                   Avellaneda Av.         1800        1800
# 110801                   Avellaneda Av.         1800        1800
# 110802                   Avellaneda Av.         1800        1800
# 110805                   Avellaneda Av.         1800        1800
# 110811                   Avellaneda Av.         1800        1800
# 117141                          Cosquín         4500        4684
# 161606                          Bragado       6200.0        6248
# 176830                     Río Colorado         4400        4430
# 203824  Estado Plurinacional de Bolivia         2000        2030
# 208724                          Terrada         2100        2115
# 209156                       Viale Luis         1700        1774
# 241601                           Deheza         4500        4552
# 248544                        Jaramillo         2800        2890
# 254764                           Monroe         4300        4335
# 258809                          Pacheco         1900        1953
# 261743                          Pacheco         2100        2107
# 265210                         Condarco       5700.0        5755
# 267815                           Achega       3000.0        3017
# 268245                         Argerich       4600.0        4629
# 284356                       Cramer Av.         1800        1869
# 298064         11 de Septiembre de 1888         3700        3737
# 305731              Ortiz de Ocampo Av.         2700        2707
# 308096                  García Teodoro          2300        2380
# 317946    Fray Justo Santa María de Oro         2700        2723
# 322838                 De Los Incas Av.         4400        4425
# 325978                          Lugones         1400        1431
# 360885    Magariños Cervantes Alejandro         2100      2185.0
#
#                        direccion_normalizada ubicacion  \
# 90                   PELLEGRINI, CARLOS 1337    Exacta
# 28042                            SARANDI 385        LA
# 76626                    DIAZ VELEZ AV. 5477    Exacta
# 81191                    ACEVEDO, EDUARDO 48    Exacta
# 83670                    ACEVEDO, EDUARDO 24    Exacta
# 83672                    ACEVEDO, EDUARDO 42    Exacta
# 84104                    ACEVEDO, EDUARDO 62    Exacta
# 95653                    CASTAÑARES AV. 1310    Exacta
# 110799                   AVELLANEDA AV. 1800    Exacta
# 110800                   AVELLANEDA AV. 1800        LD
# 110801                   AVELLANEDA AV. 1800        LD
# 110802                   AVELLANEDA AV. 1800        LD
# 110805                   AVELLANEDA AV. 1800        LD
# 110811                   AVELLANEDA AV. 1800        LD
# 117141                          COSQUIN 4684    Exacta
# 161606                          BRAGADO 6248        LA
# 176830                     RIO COLORADO 4430    Exacta
# 203824  ESTADO PLURINACIONAL DE BOLIVIA 2030       NaN
# 208724                          TERRADA 2115       NaN
# 209156                      VIALE, LUIS 1774    Exacta
# 241601                           DEHEZA 4552    Exacta
# 248544                        JARAMILLO 2890    Exacta
# 254764                           MONROE 4335        LA
# 258809                          PACHECO 1953    Exacta
# 261743                          PACHECO 2107        LA
# 265210                         CONDARCO 5755    Exacta
# 267815                           ACHEGA 3017    Exacta
# 268245                         ARGERICH 4629    Exacta
# 284356                       CRAMER AV. 1869       NaN
# 298064         11 DE SEPTIEMBRE DE 1888 3737    Exacta
# 305731                  ORTIZ DE OCAMPO 2707    Exacta
# 308096                  GARCIA, TEODORO 2380    Exacta
# 317946     FRAY JUSTO SANTAMARIA DE ORO 2723    Exacta
# 322838                 DE LOS INCAS AV. 4425    Exacta
# 325978                          LUGONES 1431        LA
# 360885                                   NaN    Exacta
#
#              nombre_cientifico ancho_acera estado_plantera ubicacion_plantera  \
# 90           Howea forsteriana         4.5         Ocupada            Regular
# 28042   Fraxinus pennsylvanica           3         Ocupada            Regular
# 76626    Platanus x acerifolia           6         Ocupada            Regular
# 81191           Ceiba speciosa         3.2         Ocupada            Regular
# 83670             Tipuana tipu         3.2         Ocupada            Regular
# 83672             Tipuana tipu         3.2         Ocupada            Regular
# 84104             Tipuana tipu         3.2         Ocupada            Regular
# 95653          No identificado           6    Sobreocupada            Regular
# 110799   Platanus x acerifolia           4         Ocupada             Ochava
# 110800   Platanus x acerifolia         5.5         Ocupada             Ochava
# 110801   Platanus x acerifolia         5.5         Ocupada             Ochava
# 110802   Platanus x acerifolia         5.5         Ocupada            Regular
# 110805   Platanus x acerifolia         5.5         Ocupada            Regular
# 110811   Platanus x acerifolia         5.5         Ocupada            Regular
# 117141           Acer palmatum           4         Ocupada            Regular
# 161606  Fraxinus pennsylvanica         3.2         Ocupada            Regular
# 176830         No identificado           2    Sobreocupada            Regular
# 203824         Ficus benjamina         4.4         Ocupada            Regular
# 208724   Jacaranda mimosifolia         3.2         Ocupada            Regular
# 209156         No identificado         3.2         Ocupada            Regular
# 241601  Fraxinus pennsylvanica         4.0         Ocupada            Regular
# 248544  Fraxinus pennsylvanica         2.2         Ocupada            Regular
# 254764  Fraxinus pennsylvanica         3.6         Ocupada            Regular
# 258809  Fraxinus pennsylvanica         4.5         Ocupada            Regular
# 261743         Ficus benjamina         4.2         Ocupada            Regular
# 265210   Platanus x acerifolia         4.4         Ocupada            Regular
# 267815  Fraxinus pennsylvanica         4.4    Sobreocupada            Regular
# 268245         Tilia x moltkei         4.4         Ocupada            Regular
# 284356      Fraxinus excelsior         6.6         Ocupada     Fuera de línea
# 298064         Melia azedarach         4.4         Ocupada            Regular
# 305731      Fraxinus excelsior           3         Ocupada            Regular
# 308096  Fraxinus pennsylvanica         3.2         Ocupada            Regular
# 317946   Platanus x acerifolia         3.2         Ocupada            Regular
# 322838   Platanus x acerifolia           8         Ocupada            Regular
# 325978   Platanus x acerifolia         4.6         Ocupada            Regular
# 360885   Jacaranda mimosifolia         4.5         Ocupada            Regular
#
#        nivel_plantera  diametro_altura_pecho  altura_arbol
# 90            Elevada                    3.0          40.0
# 28042      Bajo nivel                   19.0          40.0
# 76626         Elevada                   35.0          40.0
# 81191         A nivel                   53.0          40.0
# 83670         A nivel                   61.0          40.0
# 83672         A nivel                   57.0          40.0
# 84104         A nivel                   72.0          40.0
# 95653         Elevada                   54.0          40.0
# 110799     Bajo nivel                   64.0          40.0
# 110800        A nivel                   57.0          40.0
# 110801     Bajo nivel                   41.0          40.0
# 110802     Bajo nivel                   41.0          40.0
# 110805        A nivel                   41.0          40.0
# 110811        A nivel                   57.0          40.0
# 117141        A nivel                   53.0          40.0
# 161606        A nivel                   32.0          40.0
# 176830        A nivel                    0.0          40.0
# 203824        A nivel                    6.0          40.0
# 208724        Elevada                   35.0          40.0
# 209156        A nivel                   39.0          40.0
# 241601        A nivel                   30.0          40.0
# 248544        A nivel                   45.0          40.0
# 254764        A nivel                   15.0          40.0
# 258809        Elevada                   25.0          40.0
# 261743        Elevada                   48.0          40.0
# 265210        A nivel                   55.0          40.0
# 267815        Elevada                   28.0          40.0
# 268245        A nivel                   40.0          40.0
# 284356        Elevada                   28.0          40.0
# 298064        Elevada                   11.0          40.0
# 305731        Elevada                   40.0          40.0
# 308096        A nivel                   26.0          40.0
# 317946        A nivel                   65.0          40.0
# 322838        A nivel                    1.0          40.0
# 325978        A nivel                  116.0          40.0
# 360885        A nivel                   14.0          40.0

# %%
datos_arboles[datos_arboles["altura_arbol"]==altura_max].shape
# Out:
# (36, 17)

# %% [markdown]
# **5. Cual es el promedio de la altura de los arboles?**

# %%
datos_arboles["altura_arbol"].mean()
# Out:
# 9.036131504572811

# %% [markdown]
# ### Conclusion
#
# La exploracion de los datos es una tarea detallista y ES MUY CONVENIENTE que este orientada a un objetivo, es decir, en busqueda de que estamos?.
#
# Todo va a ser relativo en cuanto a la situacion a la que correspondan los datos, que hacemos con los valores nulos? Puede haber duplicados? Que significan las columnas? etc etc etc..

# %% [markdown]
# A continuacion dejo algunas paginas de donde se pueden descargar datasets (archivos con datos) de diversos temas.
#
# **Links para datasets**
#
# https://www.kaggle.com/
#
# https://archive.ics.uci.edu/ml/datasets.php
#
# https://data.buenosaires.gob.ar/dataset
#
# https://gobiernoabierto.cordoba.gob.ar/data/datos-abiertos
